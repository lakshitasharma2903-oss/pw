# %% [markdown]
# # LOGICAL FUNCTION AND LOOKUP ASSIGNMENT

# %% [markdown]
# Que.1 Write a formula to check if the marks in cellB2 are greater than or equal 40 .if yes ,return "Pass",other"Fail".
#
#
# Ans. FORMULA: =IF(B2>=40,"Pass","Fail")
# ✒ EXPLAINATION: This formula checks the value in cellB2 and returns.
# * "Press" if B2 is 40 or greater.
# * "Fail" if B2 is less than 40.

# %% [markdown]
# Que.2 A company gives a bonus if sales are above 40,000 and attendence is greater than or equal to 90%.Write a formula to Calculate whether the employee will get a bonus or not.
#
#
# ANS. FORMULA: =IF(AND[B2>40000,C2>=0.9),"Bonus","No bonus"

# %% [markdown]
# Que.3 Write a nested if formula.IF marks in B2>90"A",>75"B",>50"C",otherwise "
# "fail".
#
#
# ANS. This nested IF formula checks marks in B2 and returns.
# * "A" ifB2>90
# * "B"  if B2>75
# * "C"  IF B2>50
# * "FAIL"otherwise

# %% [markdown]
# Que.4 Find company the department of employee ID=E103. Also explain which LOOKUP function is used and why?

# %% [markdown]
# Ans: The department of employee id =103,is **FINANCE**.
# If which we used vlookup function ,because the data is givien in vertical order.And formula is =Vlookup(E103,table array,3,False).

# %% [markdown]
# Que5. A company has set the following commission struture for its sales team.
# IF a sales person achieves sales of rupess 45000 use the vlookup function to determine the commission rate applicable .

# %%
from google.colab import files
upload =files.upload()
# Out:
#      <input type="file" id="files-7cef6ffa-e922-45fb-ae2c-66b6d6ed1e5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7cef6ffa-e922-45fb-ae2c-66b6d6ed1e5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Que.6The HR department maintains the following leves records of employees on us or not. Write an if function to check whether an employee has Exceeded their allowed leave balance.
# * If leaves taken>allowed leaves display "Exceeded"
# * otherwise ,display "ok"

# %%
from google.colab import files
upload =files.upload()
# Out:
#      <input type="file" id="files-cca4e10d-2f45-408d-8ffd-8eb6c72dd686" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cca4e10d-2f45-408d-8ffd-8eb6c72dd686">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Que.7 Find the salary of employee ID =E105 using INDEX MATCH

# %%
from google.colab import files
upload =files.upload()
# Out:
#      <input type="file" id="files-65bfe819-83e5-48a5-bb59-d3ce7f9646a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65bfe819-83e5-48a5-bb59-d3ce7f9646a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Que.8 Use the Xlookup function to find the department of the employee with employee id E303

# %%
from google.colab import files
upload =files.upload()
# Out:
#      <input type="file" id="files-2f3b9664-31fc-48ae-8561-c6ec3d0f281b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f3b9664-31fc-48ae-8561-c6ec3d0f281b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
